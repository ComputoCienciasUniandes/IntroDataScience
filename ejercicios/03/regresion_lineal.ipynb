# %%
import numpy as np
import matplotlib.pyplot as plt
import sklearn.model_selection
import sklearn.linear_model

# %matplotlib inline

# %%
data = np.loadtxt("notas_andes.dat", skiprows=1)

# %%
Y = data[:,4]
X = data[:,:4]

X_train, X_test, Y_train, Y_test = sklearn.model_selection.train_test_split(X, Y, test_size=0.3)

print(np.shape(Y_train), np.shape(X_train))
# Out:
# (48,) (48, 4)

# %%
regresion = sklearn.linear_model.LinearRegression()
regresion.fit(X_train, Y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
print(regresion.coef_, regresion.intercept_)
print(regresion.score(X_train,Y_train), regresion.score(X_test,Y_test))
# Out:
# [0.10055502 0.17393423 0.04236203 0.22675176] 1.8916369582430885
# 0.5652030738068577 0.43335789895491783

# %%
plt.figure(figsize=(8,8))
labels = ["Fisica I", "Fisica II", "Alg Lin", "Calc Dif"]

for i, label in enumerate(labels):
    plt.subplot(2,2,i+1)
    plt.scatter(X_train[:,i], Y_train)
    plt.scatter(X_train[:,i], regresion.predict(X_train), marker='^')
    plt.xlabel(label)
    plt.ylabel('PGA')
